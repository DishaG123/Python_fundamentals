# %% [markdown]
# Python is interpreted, high-level and object-oriented language.
# Easiest language to learn.

# %% [markdown]
# Variables and constants

# %%
2+4
# Out:
# 6

# %%
x = 2
y = 4
z = x + y
z
# Out:
# 6

# %% [markdown]
# Strings can be added too

# %%
N = 'abc'
N +'def'
# Out:
# 'abcdef'

# %%
N[1]
# Out:
# 'b'

# %% [markdown]
# **List**
#
# list can have different types of datatypes mixed.
# Similar to arrays but can have various datatypes in one list.
# lists are mutable.

# %%
list_1 = [1,2,'abc',35.88]
list_2 = [33,44,55]
list_1[3]
# Out:
# 35.88

# %%
list_3 = [list_1,list_2]
list_3
# Out:
# [[1, 2, 'abc', 35.88], [33, 44, 55]]

# %%
list_1.append(1)
list_1
# Out:
# [1, 2, 'abc', 35.88, 1]

# %%
list_1.insert(2,4)
list_1
# Out:
# [1, 2, 4, 'abc', 35.88, 1]

# %%
list_1.remove(1)

# %%
list_1
# Out:
# [2, 4, 'abc', 35.88, 1]

# %% [markdown]
# if you pop without index last value is removed.

# %%
list_1.pop(1)
# Out:
# 4

# %%
del list_1[2:]

# %%
list_1
# Out:
# [2, 'abc']

# %%
list_1.extend([24,45,56,67])
list_1
# Out:
# [2, 'abc', 24, 45, 56, 67]

# %% [markdown]
# list.append(x)
# Add an item to the end of the list. Equivalent to a[len(a):] = [x].
#
# list.extend(iterable)
# Extend the list by appending all the items from the iterable. Equivalent to a[len(a):] = iterable.
#
# list.insert(i, x)
# Insert an item at a given position. The first argument is the index of the element before which to insert, so a.insert(0, x) inserts at the front of the list, and a.insert(len(a), x) is equivalent to a.append(x).
#
# list.remove(x)
# Remove the first item from the list whose value is equal to x. It raises a ValueError if there is no such item.
#
# list.pop([i])
# Remove the item at the given position in the list, and return it. If no index is specified, a.pop() removes and returns the last item in the list. (The square brackets around the i in the method signature denote that the parameter is optional, not that you should type square brackets at that position. You will see this notation frequently in the Python Library Reference.)
#
# list.clear()
# Remove all items from the list. Equivalent to del a[:].
#
# list.index(x[, start[, end]])
# Return zero-based index in the list of the first item whose value is equal to x. Raises a ValueError if there is no such item.
#
# The optional arguments start and end are interpreted as in the slice notation and are used to limit the search to a particular subsequence of the list. The returned index is computed relative to the beginning of the full sequence rather than the start argument.
#
# list.count(x)
# Return the number of times x appears in the list.
#
# list.sort(key=None, reverse=False)
# Sort the items of the list in place (the arguments can be used for sort customization, see sorted() for their explanation).
#
# list.reverse()
# Reverse the elements of the list in place.
#
# list.copy()
# Return a shallow copy of the list. Equivalent to a[:].
#
# list.min()
# list.max()
# list.sum()

# %% [markdown]
# Using list as stack

# %%
stack = [1,2,3,4]
stack.append(5)
stack
# Out:
# [1, 2, 3, 4, 5]

# %%
stack.pop()
# Out:
# 5

# %%
stack
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# Queue implementations
#
#
# ( from collections import deque :
# queue = deque(["Eric", "John", "Michael"])
# queue.append()
# ![](http://)queue.popleft)

# %%
queue=[1,2,3,4]
queue.append(5)

# %%
queue
# Out:
# [1, 2, 3, 4, 5]

# %%
queue.pop(0)
queue
# Out:
# [2, 3, 4, 5]

# %%
squares = list(map(lambda x: x**2, range(10)))
squares
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares = [x**2 for x in range(10)]
squares
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
[(x, y) for x in [1,2,3] for y in [3,1,4] if x != y]
# Out:
# [(1, 3), (1, 4), (2, 3), (2, 1), (2, 4), (3, 1), (3, 4)]

# %% [markdown]
# **Tuple**

# %% [markdown]
# immutable
#
# tuple.count()
# tuple.index()
#
# iteration speed is more than list

# %%
tup = (21,24,34,56)

# %%
tup[1]
# Out:
# 24

# %% [markdown]
# **Set**

# %%
s = {12,3,2,4,13,2,34}

# %% [markdown]
# The order is never defined
#
# uses hash and hence speed increases.

# %%
s
# Out:
# {2, 3, 4, 12, 13, 34}

# %% [markdown]
# Supports everything as list except for indexing and duplication

# %% [markdown]
# **Dictionaries**

# %%
data = {1 : 'a', 2: 'b', 5:'c'}
data
# Out:
# {1: 'a', 2: 'b', 5: 'c'}

# %%
data[5]
# Out:
# 'c'

# %% [markdown]
# we can use index in get

# %%
data.get(1,'NA')
# Out:
# 'a'

# %%
data_1 = dict(zip(list_1,list_2))
data_1
# Out:
# {2: 33, 'abc': 44, 24: 55}

# %%
data_1[6]= 22

# %%
data_1
# Out:
# {2: 33, 'abc': 44, 24: 55, 6: 22}

# %%
data.keys()
# Out:
# dict_keys([1, 2, 5])

# %%
data.values()
# Out:
# dict_values(['a', 'b', 'c'])

# %%
del data_1[2]

# %% [markdown]
# Nested dictionaries is allowed

# %%
data_1
# Out:
# {'abc': 44, 24: 55, 6: 22}

# %% [markdown]
# **Pointers**

# %% [markdown]
# this function gives the address of the saved variable

# %%
x=3
id(x)
# Out:
# 94076360274624

# %% [markdown]
# If data stored is same both the variables point to the same memory

# %%
a = x
id(a)
# Out:
# 94076360274624

# %%
id(10)
# Out:
# 94076360274848

# %% [markdown]
# **Datatypes**

# %%
a = 1 #int
b = 2.1 #float 
c = 1 + 1j #complex
#Bool

# %%
b =list() #list
type(b)
# Out:
# list

# %%
c = set()  #set
d = tuple() #tuple
st = 'abc' #string
range(10) #range
# Out:
# range(0, 10)

# %%
list(range(2,20,4))
# Out:
# [2, 6, 10, 14, 18]

# %%
c =dict() #dictionary

# %% [markdown]
# **Operators**
#
# arithmetic
#
# assignment (x +=2)
#
# unary
#
# relational
#
# logical (AND OR NOT )

# %% [markdown]
# **Numerical system conversions**

# %%
bin(25)
# Out:
# '0b11001'

# %%
0b11001
# Out:
# 25

# %%
oct(25)
# Out:
# '0o31'

# %%
hex(25)
# Out:
# '0x19'

# %% [markdown]
# swapping of variables

# %%
a,b = b,a

# %% [markdown]
# Bitwise operators
#
# complement ~
#
# and &
#
# or |
#
# xor ^
#
# left shift <<
#
# right shift >>

# %% [markdown]
# Mathematical functions

# %%
import math

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
math.floor(2.1)
# Out:
# 2

# %%
math.ceil(2.1)
# Out:
# 3

# %%
3**2
# Out:
# 9

# %%
math.pow(3,2)
# Out:
# 9.0

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# ref. https://docs.python.org/3/library/math.html

# %% [markdown]
# **user input**

# %%
z1 =2
z1 =input(z1)
# Out:
# 23

# %%
z1 = int(z1)

# %%
z1
# Out:
# 3

# %%
ch = input('enter a character')[0]
# Out:
# enter a characterabc

# %%
ch
# Out:
# 'a'

# %%
eval(input())
# Out:
# 1+2
# 3

# %% [markdown]
# use sys.argv() to take input from command window

# %% [markdown]
# **Conditional execution**
#
# if_elif_else

# %%
w=3

if (w==3): 
    print('false')
elif(w==2):
    print('  ')
else :
    print ('true')
# Out:
# false

# %% [markdown]
# **Loops**
#
# while
#
# for

# %%
i = 1
while(i<=5):
    print("hellooo")
    i +=1
# Out:
# hellooo
# hellooo
# hellooo
# hellooo
# hellooo

# %%
x = [1,2,3,4,5]
for i in x:# in range(1,6)
    print(i**3)
# Out:
# 1
# 8
# 27
# 64
# 125

# %%
y = 'DISHA'
for i in y:
    print(i)
# Out:
# D
# I
# S
# H
# A

# %% [markdown]
# Break : exit the loop
#
# Continue : don't do anything for the iteration but continue the loop's execution (skip next statements)
#
# Pass : do nothing

# %%
print('#', end ='  ')
print('#', end='')
# Out:
# #  #

# %% [markdown]
# **for_else**

# %%
for i in range(1,4):
    if(i == 5):
        print(5)
else:
    print('not found')# only executed once
# Out:
# not found
